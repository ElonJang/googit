# %% [markdown]
# # Hello world
# ## hello world
# ### hello world
#
# 1. hello world
# 2. hello world
# 3. hello world
#
# - hello world
# - hello world
# - hello world
#
# * hello world
# * hello world
# * hello world

# %% [markdown]
# > hello world
#
# hello world *hello* **world** hello

# %% [markdown]
# markdown table generator

# %%
# !ls
# Out:
#  001일차_numpy.ipynb
#  002일차_pandas.ipynb
#  003일차_기본실습_1.ipynb
#  004일차_Graph_Visualization.ipynb
#  005일차_seaborn과_potly.ipynb
# '006일차_1_코로나데이터분석(성별, 지역).ipynb'
# '006일차_2_코로나데이터분석(한국확진자와 사망자분석).ipynb'
#  006일차_3_세계데이터분석.ipynb
#  007일차_1_통계이론.ipynb
#  007일차_2_확률.ipynb
#  007일차_3_미분.ipynb
# '007일차_4_정규분포, 선형,비선형.ipynb'
#  007일차_5_행렬.ipynb
# '2_결측값(NaN, None)처리.ipynb'
#  Inf_data_analysis.ipynb
# 'Untitled Folder'
#  Untitled.ipynb
#  daily_Confirmed.csv
#  daily_Deceased.csv
#  ex_02.ipynb
#  rawData.csv
#  region.csv
#  time_series_covid_19_confirmed.csv
#  time_series_covid_19_deaths.csv
#  time_series_covid_19_recovered.csv
#  total.csv
#  학교점수.csv

# %%
! ls -al
# Out:
# 합계 11348
# drwxrwxr-x 4 root root    4096  3월 13 07:39  .
# drwxrwxr-x 3 root root    4096  1월 23 10:52  ..
# drwxrwxr-x 2 root root    4096  3월 13 07:37  .ipynb_checkpoints
# -rw-rw-r-- 1 root root   65953  1월 16 14:16  001일차_numpy.ipynb
# -rw-rw-r-- 1 root root  164387  1월 19 14:03  002일차_pandas.ipynb
# -rw-rw-r-- 1 root root  132011  1월 19 14:43  003일차_기본실습_1.ipynb
# -rw-rw-r-- 1 root root 1016616  1월 16 14:21  004일차_Graph_Visualization.ipynb
# -rw-rw-r-- 1 root root 4749706  1월 16 14:21  005일차_seaborn과_potly.ipynb
# -rw-rw-r-- 1 root root  877674  1월 16 14:21 '006일차_1_코로나데이터분석(성별, 지역).ipynb'
# -rw-rw-r-- 1 root root 3764672  1월 16 14:21 '006일차_2_코로나데이터분석(한국확진자와 사망자분석).ipynb'
# -rw-rw-r-- 1 root root  381548  1월 16 14:21  006일차_3_세계데이터분석.ipynb
# -rw-rw-r-- 1 root root    4094  1월 16 14:21  007일차_1_통계이론.ipynb
# -rw-rw-r-- 1 root root   14192  1월 16 14:21  007일차_2_확률.ipynb
# -rw-rw-r-- 1 root root   82328  1월 16 14:21  007일차_3_미분.ipynb
# ...

# %% [markdown]
# !pip3 in install bs4

# %% [markdown]
# !touch 001.py

# %% [markdown]
# %run 001.py

# %% [markdown]
# %%time
#
# print(sum(range(1, 100000000)))

# %%
# %%time
print(sum(range(1, 100000)))
# Out:
# 4999950000
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 2.92 ms

# %%
# %%timeit

print(sum(range(1, 1000)))
# Out:
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# 499500
# ...

# %%
def f(x,y):
    return x + y

# %%
f(3,6)
# Out:
# 9

# %%
f?

# %%
f??

# %%
# f+시프트+탭 누르면 툴팁형태의 도움말이 뜬다

# %%
import random

# random.rand + 탭을 누르면 자동완성 기능, 실수를 줄이므로 권장
random.randint(1, 10)
# Out:
# 3

# %% [markdown]
# ## 이미지를 끌어당겨서 업로드합니다.

# %%
# %magic #설명이 쭉 나온다

# %%
l =[100, 200, 300]
l.# .을 찍고 탭을 누르면 쓸 수 있는 메서드 들이 쭉 나온다.
